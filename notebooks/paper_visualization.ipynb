# %%
# Extend the original data with two new attributes: Data Points and Number of Categories

data_extended = {
    "Attribute": [
        "Axes Orientation", "Axes Orientation",
        "Numerical Range", "Numerical Range", "Numerical Range",
        "Category Colors", "Category Colors",
        "Text Length",
        "Axes Count", "Axes Count", "Axes Count",
        "Data Points", "Data Points",
        "Number of Categories", "Number of Categories", "Number of Categories"
    ],
    "Category": [
        "Vertical", "Horizontal",
        "<1", "1-9", "3-4 digits",
        "Distinct", "Single",
        "1–15 chars",
        "3", "4", "5",
        "50", "Other",
        "3", "4", "5"
    ],
    "Percentage": [
        80, 20,
        50, 25, 25,
        60, 40,
        100,
        30, 40, 30,
        70, 30,
        50, 25, 25
    ]
}

df_ext = pd.DataFrame(data_extended)

# Pivot for stacked bar chart
pivot_df_ext = df_ext.pivot(index='Attribute', columns='Category', values='Percentage').fillna(0)

# Plot extended stacked bar chart
pivot_df_ext.plot(kind='bar', stacked=True, figsize=(13, 7), colormap='tab20')
plt.ylabel("Percentage (%)")
plt.title("Stacked Bar Plot: Real-World Image Attribute Distributions (Extended)")
plt.xticks(rotation=30, ha='right')
plt.legend(title="Category", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Extend the original data with two new attributes: Data Points and Number of Categories

data_extended = {
    "Attribute": [
        "Axes Orientation", "Axes Orientation",
        "Numerical Range", "Numerical Range", "Numerical Range",
        "Category Colors", "Category Colors",
        "Text Length",
        "Axes Count", "Axes Count", "Axes Count",
        "Data Points", "Data Points","Data Points",
        "Number of Categories", "Number of Categories", "Number of Categories"
    ],
    "Category": [
        "Vertical", "Horizontal",
        "<1", "1-9", "3-4 digits",
        "Distinct", "Single",
        "1–15 chars",
        "3", "4", "5",
        "70", "30", "20",
        "3", "4", "5"
    ],
    "Percentage": [
        80, 20,
        50, 25, 25,
        60, 40,
        100,
        30, 40, 30,
        60, 30, 10,
        50, 25, 25
    ]
}

df_ext = pd.DataFrame(data_extended)

# Filter out the row with Attribute "Text Length"
df_filtered = df_ext[df_ext["Attribute"] != "Text Length"]

# Pivot and replot
pivot_df_filtered = df_filtered.pivot(index='Attribute', columns='Category', values='Percentage').fillna(0)

# Plot updated stacked bar chart
ax = pivot_df_filtered.plot(kind='bar', stacked=True, figsize=(13, 7), colormap='tab20')
plt.ylabel("Percentage (%)")
plt.title("Stacked Bar Plot: Real-World Image Attribute Distributions (Updated)")
plt.xticks(rotation=30, ha='right')
plt.legend(title="Label", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
#### this is the one i am using
import pandas as pd
import matplotlib.pyplot as plt
data_extended = {
    "Attribute": [
        "Axes Orientation", "Axes Orientation",
        "Numerical Range", "Numerical Range", "Numerical Range",
        "Category Colors", "Category Colors",
        "Text Length",
        "Axes Count", "Axes Count", "Axes Count",
        "Data Points", "Data Points","Data Points",
        "Number of Categories", "Number of Categories", "Number of Categories"
    ],
    "Category": [
        "Vertical", "Horizontal",
        "<1", "1-9", "3-4 digits",
        "Distinct", "Single",
        "1–15 chars",
        "3", "4", "5",
        "70", "30", "20",
        "3", "4", "5"
    ],
    "Percentage": [
        80, 20,
        50, 25, 25,
        60, 40,
        100,
        30, 40, 30,
        60, 30, 10,
        50, 25, 25
    ]
}

df_ext = pd.DataFrame(data_extended)

# Filter out the row with Attribute "Text Length"
df_filtered = df_ext[df_ext["Attribute"] != "Text Length"]
# Pivot and replot
pivot_df_filtered = df_filtered.pivot(index='Attribute', columns='Category', values='Percentage').fillna(0)
ax = pivot_df_filtered.plot(kind='bar', stacked=True, figsize=(13, 7), colormap='tab20')
plt.ylabel("Percentage (%)")
plt.title("Stacked Bar Plot: Real-World Image Attribute Distributions")

# Add labels inside bar segments
for container_idx, container in enumerate(ax.containers):
    category_label = pivot_df_filtered.columns[container_idx]
    for bar in container:
        height = bar.get_height()
        if height > 5:
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_y() + height / 2,
                category_label,
                ha='center', va='center',
                fontsize=9, color='white'
            )

plt.xticks(rotation=30, ha='right')
ax.get_legend().remove()  # Remove legend since labels are now inside the bars
plt.tight_layout()
plt.show()

# %%
##syntheric data 

#### this is the one i am using 
data_extended = {
    "Attribute": [
        "Axes Orientation",
        "Numerical Range", "Numerical Range", "Numerical Range",
        "Category Colors",
        "Text Length",
        "Axes Count", "Axes Count", "Axes Count",
        "Data Points",
        "Number of Categories", "Number of Categories", "Number of Categories"
    ],
    "Category": [
        "Vertical", 
        "<1", "1-9", "3-4 digits",
        "Distinct",
        "1–15 chars",
        "3", "4", "5",
        "100",
        "3", "4", "5"
    ],
    "Percentage": [
        100,
        50, 25, 25,
        100,
        100,
        30, 40, 30,
        100,
        50, 25, 25
    ]
}

df_ext = pd.DataFrame(data_extended)

# Filter out the row with Attribute "Text Length"
df_filtered = df_ext[df_ext["Attribute"] != "Text Length"]
# Pivot and replot
pivot_df_filtered = df_filtered.pivot(index='Attribute', columns='Category', values='Percentage').fillna(0)
ax = pivot_df_filtered.plot(kind='bar', stacked=True, figsize=(13, 7), colormap='tab20')
plt.ylabel("Percentage (%)")
plt.title("Stacked Bar Plot: synthetic plots Attribute Distributions")

# Add labels inside bar segments
for container_idx, container in enumerate(ax.containers):
    category_label = pivot_df_filtered.columns[container_idx]
    for bar in container:
        height = bar.get_height()
        if height > 5:
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_y() + height / 2,
                category_label,
                ha='center', va='center',
                fontsize=9, color='white'
            )

plt.xticks(rotation=30, ha='right')
ax.get_legend().remove()  # Remove legend since labels are now inside the bars
plt.tight_layout()
plt.show()

# %%
# Create grouped bar plot version of the same data (each label appears as a separate bar per attribute)

# We already have the filtered DataFrame from previous step
# Plot grouped bar chart instead of stacked
plt.figure(figsize=(13, 7))
sns.barplot(data=df_filtered, x="Attribute", y="Percentage", hue="Category", palette="tab20")

plt.ylabel("Percentage (%)")
plt.title("Grouped Bar Plot: Real-World Image Attribute Distributions (Updated)")
plt.xticks(rotation=30, ha='right')
plt.legend(title="Label", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Plot grouped bar chart with wider bars and no gridlines
plt.figure(figsize=(13, 7))
sns.set_style("white")  # Remove background grid
barplot = sns.barplot(
    data=df_filtered,
    x="Attribute",
    y="Percentage",
    hue="Category",
    palette="tab20",
    dodge=True
)

# Adjust bar width by manipulating bar container
for bar in barplot.patches:
    current_width = bar.get_width()
    bar.set_width(current_width * 1.2)

plt.ylabel("Percentage (%)")
plt.title("Grouped Bar Plot: Real-World Image Attribute Distributions")
plt.xticks(rotation=30, ha='right')
plt.legend(title="Label", bbox_to_anchor=(1.05, 1), loc='upper left')
sns.despine()  # Remove top/right spines
plt.tight_layout()
plt.show()

# %%
# Create real-world and synthetic data as side-by-side comparison plots

import pandas as pd
import matplotlib.pyplot as plt

# Real-world data
real_data = {
    "Attribute": [
        "Axes Orientation", "Axes Orientation",
        "Numerical Range", "Numerical Range", "Numerical Range",
        "Category Colors", "Category Colors",
        "Text Length",
        "Axes Count", "Axes Count", "Axes Count",
        "Data Points", "Data Points", "Data Points",
        "Number of Categories", "Number of Categories", "Number of Categories"
    ],
    "Category": [
        "Vertical", "Horizontal",
        "<1", "1-9", "3-4 digits",
        "Distinct", "Single",
        "1–15 chars",
        "3", "4", "5",
        "70", "30", "20",
        "3", "4", "5"
    ],
    "Percentage": [
        80, 20,
        50, 25, 25,
        60, 40,
        100,
        30, 40, 30,
        60, 30, 10,
        50, 25, 25
    ]
}

# Synthetic data
synthetic_data = {
    "Attribute": [
        "Axes Orientation",
        "Numerical Range", "Numerical Range", "Numerical Range",
        "Category Colors",
        "Text Length",
        "Axes Count", "Axes Count", "Axes Count",
        "Data Points",
        "Number of Categories", "Number of Categories", "Number of Categories"
    ],
    "Category": [
        "Vertical",
        "<1", "1-9", "3-4 digits",
        "Distinct",
        "1–15 chars",
        "3", "4", "5",
        "100",
        "3", "4", "5"
    ],
    "Percentage": [
        100,
        50, 25, 25,
        100,
        100,
        30, 40, 30,
        100,
        50, 25, 25
    ]
}

# Convert to DataFrames
df_real = pd.DataFrame(real_data)
df_synth = pd.DataFrame(synthetic_data)

# Filter out Text Length
df_real = df_real[df_real["Attribute"] != "Text Length"]
df_synth = df_synth[df_synth["Attribute"] != "Text Length"]

# Pivot both
pivot_real = df_real.pivot(index='Attribute', columns='Category', values='Percentage').fillna(0)
pivot_synth = df_synth.pivot(index='Attribute', columns='Category', values='Percentage').fillna(0)

# Plot side-by-side
fig, axes = plt.subplots(1, 2, figsize=(16, 7), sharey=True)

# Real-world plot
ax1 = pivot_real.plot(kind='bar', stacked=True, ax=axes[0], colormap='tab20')
ax1.set_title("Real-World Attribute Distributions")
ax1.set_ylabel("Percentage (%)")
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=30, ha='right')
ax1.get_legend().remove()

for container_idx, container in enumerate(ax1.containers):
    label = pivot_real.columns[container_idx]
    for bar in container:
        height = bar.get_height()
        if height > 5:
            ax1.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_y() + height / 2,
                label,
                ha='center', va='center',
                fontsize=9, color='white'
            )

# Synthetic plot
ax2 = pivot_synth.plot(kind='bar', stacked=True, ax=axes[1], colormap='tab20')
ax2.set_title("Synthetic Attribute Distributions")
ax2.set_ylabel("")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=30, ha='right')
ax2.get_legend().remove()

for container_idx, container in enumerate(ax2.containers):
    label = pivot_synth.columns[container_idx]
    for bar in container:
        height = bar.get_height()
        if height > 5:
            ax2.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_y() + height / 2,
                label,
                ha='center', va='center',
                fontsize=9, color='white'
            )

plt.suptitle("Real-World vs Synthetic Attribute Distributions", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
